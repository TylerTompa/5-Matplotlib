# %% [markdown]
# # In this notebook we will analyze ride sharing data.
# # First we will examine a bubble plot displaying the relationship between average fare, total rides, total drivers, and city types.
# # Then we will examine various pie charts including:
# # 1. Percentage of total fares by city type
# # 2. Percentage of total rides by city type.
# # 3. Percentage of total drivers by city type.

# %%
# %matplotlib inline

# %%
# We must first import relevant packages to this assignment.
# We will use pandas to extract the relevant data from our dataset, and we will use matplotlib to plot said data.
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Here we define where our data is located so that we can later use it.
city_data_csv_path = "Data/city_data.csv"
ride_data_csv_path = "Data/ride_data.csv"

# %%
# This creates dataframes using the data from our relevant csv files.
city_data = pd.read_csv(city_data_csv_path)
ride_data = pd.read_csv(ride_data_csv_path)

# %%
# Here we prview our city_data dataframe so we know what data it contains.
city_data.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
# Here we prview our ride_data dataframe so we know what data it contains.
ride_data.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
# Here we merge our city_data and ride_data dataframes on the common column "city"
city_ride_merged_dataframe = pd.merge(city_data, ride_data, how="left", on=["city", "city"])
city_ride_merged_dataframe.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %% [markdown]
# ## In this section we will create our bubble plot.

# %%
# Here we calculate the total rides per city for each city type.
# First we filter our merged dataframe by city type; then we group by city, and finally finally we count the number of entries in the ride_id column.
total_rides_per_city_urban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Urban"].groupby("city")["ride_id"].count()
total_rides_per_city_suburban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Suburban"].groupby("city")["ride_id"].count()
total_rides_per_city_rural = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Rural"].groupby("city")["ride_id"].count()

# %%
# Here we calculate the average fare per city for each city type.
# First we filter our merged dataframe by city type; then we group by city, and finally we find the mean of the fare column.
average_fare_per_city_urban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Urban"].groupby("city")["fare"].mean()
average_fare_per_city_suburban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Suburban"].groupby("city")["fare"].mean()
average_fare_per_city_rural = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Rural"].groupby("city")["fare"].mean()

# %%
# Here we calculate the total number of drivers per city for each city type.
# First we filter our city_data dataframe by city type; then we group by city; and finally we find the sum of the driver_count column for each city.
# We do not use our merged dataframecontaining every ride for these series, because we do not want to count a city's drivers more than once.
total_drivers_per_city_urban = city_data[city_data["type"] == "Urban"].groupby("city")["driver_count"].sum()
total_drivers_per_city_suburban = city_data[city_data["type"] == "Suburban"].groupby("city")["driver_count"].sum()
total_drivers_per_city_rural = city_data[city_data["type"] == "Rural"].groupby("city")["driver_count"].sum()

# %%
# Here we define the data that will make up our bubble plot.
# The x-axis is defined by the total number of rides.
# The y-axis is defined by the average fare.
# The point size is defined be the total number of drivers per city
# We multiple the drivers_per_city variables by 10 so that we can better see the differences.
# The colors differentiate different city types.
plt.scatter(total_rides_per_city_urban, average_fare_per_city_urban, s=10*total_drivers_per_city_urban, color = "coral", edgecolors = "black", alpha=0.8, label="Urban", linewidths=1)
plt.scatter(total_rides_per_city_suburban, average_fare_per_city_suburban, s=10*total_drivers_per_city_suburban, color = "lightskyblue", edgecolors="black", alpha=0.8, label="Suburban", linewidths=1)
plt.scatter(total_rides_per_city_rural, average_fare_per_city_rural, s=10*total_drivers_per_city_rural, color = "gold", edgecolors="black", alpha=0.8, label="Rural", linewidths=1)

# This gives our plot a title.
plt.title("Pyber Ride Sharing Data (2016)")

# This places a legend on our plot.
# The title paramaeter allows us to title the legend,
# and the loc parameter set to best places the legend in the area with the most blank space to avoid overlapping any data.
bubble_plot_legend = plt.legend(title="City Types", loc="best")

# This allows us to redefine the size of the icons in the legend.
# Without this, the icons would correspond to the general size of the points on the plot.
# That is, the Urban icon in the legend would be noticably larger than the the Suburban icon,
# and the Suburban icon would be noticably larger than the Rural icon.
bubble_plot_legend.legendHandles[0]._sizes = [50]
bubble_plot_legend.legendHandles[1]._sizes = [50]
bubble_plot_legend.legendHandles[2]._sizes = [50]

# The following lines define our axis titles.
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")

# This allows us to add a note at the specified coordinates.
plt.text(42, 40, "Note:\nCircle size correlates\nwith driver count per city.")

# This adds a grid to the background.  Without this we would have a blank canvas.
plt.grid()

# This shows our plot and all adjustments made thereto.
plt.show()

# %% [markdown]
# ## In this section, we will create three pie charts which summarize various percentages by city type.

# %% [markdown]
# ### Here we will create a pie chart showing percentage of total fares by city type.

# %%
# To find the percentage of fares by city type, we will first select only rows with the relevant city type.
# Next we will calculate the mean of every value in the fare column.
# Finally, we will divide this by the mean of the fare column for the entire dataframe including every city type.
percentage_of_fares_urban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Urban"]["fare"].sum() / city_ride_merged_dataframe["fare"].sum()
percentage_of_fares_suburban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Suburban"]["fare"].sum() / city_ride_merged_dataframe["fare"].sum()
percentage_of_fares_rural = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Rural"]["fare"].sum() / city_ride_merged_dataframe["fare"].sum()

# %%
# Here we define a list containing the percentages of fares by city type to be used in a pie chart.
percentage_of_fares_data = [percentage_of_fares_urban, percentage_of_fares_rural, percentage_of_fares_suburban]

# Here we define the labels to be used on our pie chart.  We will use the same labels for the next two pie charts.
city_type_labels = ["Urban", "Rural", "Suburban"]

# Here we explode the Urban portion of the pie chart.  We will use the same explode settings for the next two pie charts.
city_type_explode = (0.1, 0, 0)

# Here we define the colors of our pie chart to match the Pyber company's colors.  We will use the same color settings for the next two pie charts.
city_type_colors = ["lightcoral", "gold", "lightskyblue"]

# Here we use all the settings previously defined to create our pie chart.
# We add the additional parameter of autopct="%0.1f%" to display the numerical value for each portion of the pie chart.  We also add a shadow to our chart.
plt.pie(percentage_of_fares_data, autopct="%0.1f%%", labels = city_type_labels, explode=city_type_explode, colors=city_type_colors, startangle=280, shadow=True)
plt.title("Percentage of Total Fares by City Type")
# Out:
# Text(0.5,1,'Percentage of Total Fares by City Type')

# %% [markdown]
# ### Here we will create a pie chart showing percentage of total rides by city type.

# %%
# To find the percentage of total rides by city type, we will first select only rows with the relevant city type.
# Next we will count the number of entries in the ride_id column.
# Finally, we will divide this by the number of entries in the ride_id column for the entire dataframe including every city type.
percentage_of_rides_urban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Urban"]["ride_id"].count() / city_ride_merged_dataframe["ride_id"].count()
percentage_of_rides_suburban = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Suburban"]["ride_id"].count() / city_ride_merged_dataframe["ride_id"].count()
percentage_of_rides_rural = city_ride_merged_dataframe[city_ride_merged_dataframe["type"] == "Rural"]["ride_id"].count() / city_ride_merged_dataframe["ride_id"].count()

# %%
# Here we define a list containing the percentages of total rides per city type to be used in a pie chart.
percentage_of_rides_data = [percentage_of_rides_urban, percentage_of_rides_rural, percentage_of_rides_suburban]

# We will use all the settings previous defined to create our pie chart.
# We add the additional setting of autopct="%0.1f%" to show the numerical value for each portion of the pie chart.  We also add a shadow to our chart.
# The city_labels variable was already defined when we created our pie chart displaying percentage of total fares per city type.
# The explode variable was already define when we created our pie chart displaying percentage of total fares per city type.
# The colors variable was already defined when we created our pie chart displaying percentage of total fares per city type.
plt.pie(percentage_of_rides_data, autopct="%0.1f%%", labels = city_type_labels, explode=city_type_explode, colors=city_type_colors, startangle=260, shadow=True)
plt.title("Percentage of Total Rides by City Type")
# Out:
# Text(0.5,1,'Percentage of Total Rides by City Type')

# %% [markdown]
# ### Here we will create a pie chart showing percentage of total drivers by city type.

# %%
# To find the percentage of total drivers by city type, we will first select only rows with the relevant city type
# Next we will calculate the sum of the entries in the driver_count column.
# Finally, we will divide this by the sum of the entries in the driver_count column for the entire dataframe including every city type.
# Just as when we made out bubble plot, we will use the city_data dataframe, since our merged dataframe repeats cities and their drives for every ride.
percentage_of_drivers_urban = city_data[city_data["type"] == "Urban"]["driver_count"].sum() / city_data["driver_count"].sum()
percentage_of_drivers_suburban = city_data[city_data["type"] == "Suburban"]["driver_count"].sum() / city_data["driver_count"].sum()
percentage_of_drivers_rural = city_data[city_data["type"] == "Rural"]["driver_count"].sum() / city_data["driver_count"].sum()

# %%
# Here we define a list containing the percentages of total drivers by city type to be used in a pie chart.
percentage_of_drivers_data = [percentage_of_drivers_urban, percentage_of_drivers_rural, percentage_of_drivers_suburban]

# Here we use all the settings previous defined to create our pie chart.
# We add the additional setting of autopct="%0.1f%" to show the actual value for each portion of the pie chart.  We also add a shadow to our chart.
# The city_labels variable was already defined when we created our pie chart displaying percentage of total fares per city type.
# The explode variable was already defined when we created our pie chart displaying percentage of total fares per city type.
# The colors variable was already defined when we created our pie chart displaying percentage of total fares per city type.
plt.pie(percentage_of_drivers_data, autopct="%0.1f%%", labels = city_type_labels, explode=city_type_explode, colors=city_type_colors, startangle=235, shadow=True)
plt.title("Percentage of Total Drivers by City Type")
# Out:
# Text(0.5,1,'Percentage of Total Drivers by City Type')

# %% [markdown]
# ## Trend analysis

# %% [markdown]
# If we view our bubble plot, we see a very rough linear pattern.  Rural rides, few of which there are, have high fares on average.  Suburban rides, more of which there are, have moderate fares on average.  Urban rides, many of which there are, have low fares on average.  We should be cautious in making any conclusions from this plot though, as it is difficult to tell if rural rides are more expensive because they are rural, or because there are fewer rides per city, or because there are fewer drivers per city.  Similarly, we cannot conclude whether urban rides are cheaper because they are urban, or because there are more rides per city, or because there are more drivers per city.  Simply put, there appears to be a very rough linear pattern, but there are too many variables to determine what the cause thereof is.

# %% [markdown]
# To expand on our lack of conclusion from part (1), we will view our pie chart showing percentage of total fares by city type, and see urban cities make up 62.7% of total fares; suburban cities make up 30.5%, and rural cities make up 6.8%.  Next, if we view our percent of total rides by city type, we will see 68.4%, 26.3%, and 5.3%, respectively.  Here we notice that even though urban rides make up as much as 68.4% of total rides, they produce only 62.7% of total fares.  Rural rides- on the other hand- make up only 5.3% of total rides, yet produce as much as 6.8% of total fares.
#
# In other words, the percentage of total fares produced by urban cities is less than the percentage of rides made by urban cities, and the percentage of total fares produced by rural cities is higher than the percentage of total rides made thereby.  A similar trend to rural cities can be seen in suburban cities.  What this means is that rural and suburban fares must hold more weight than urban fares, or in other words, cost more.  This can give us some confidence in concluding that the percentage of total rides has some influence on the rough linearity of the bubble plot.

# %% [markdown]
# Because we compared percentage of total fares to percentage of total rides in part (2), we will compare percentage of total fares to percentage of total drivers in part (3).  Again, if we view our pie chart showing percentage of total fares by city type, we will see that urban cities make up 62.7% of total fares; suburban cities make up 30.5%, and rural cities make up 6.8%.  From viewing the pie chart showing the percentage of total drivers by city type, we will see 80.9%, 16.5%, and 2.6%, respectively.
#
# Here the difference is much more noticeable.  Urban cities produce a percentage of total fares much lower than the percentage of drivers they have to offer, and while rural and suburban cities offer a low percentage of total drivers, they yield a much higher percentage of total fares.  From this we can conclude that the percentage of total drivers affects the fare more than the percentage of total rides by city type.
